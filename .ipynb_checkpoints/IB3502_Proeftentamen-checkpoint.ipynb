# %% [markdown]
# <img align="right" width="125" src="https://www.ou.nl/documents/40554/3255217/Logo_OU.jpg"/>
#
# <br>
#
#
# <center> <font size ="6" color='red'> IB3502 - Python Programming </font></center>
# <center> <font size ="5" color='red'> Proeftentamen</font></center>
# <br>

# %% [markdown]
# __________________

# %%
# !wget https://raw.githubusercontent.com/muratfirat78/Python/raw/main/quiz.py

from quiz import *
VisMgr = VisualManager()
tab_set = widgets.Tab([VisMgr.getQuizTab()])
open_quiz(VisMgr,9999,tab_set)
tab_set
